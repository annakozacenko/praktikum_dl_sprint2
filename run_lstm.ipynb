# %%
import torch
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
else:
    print("CUDA is not available")
# Out:
# Tesla T4

# %%
import os
os.listdir()
# Out:
# ['requirements_sprint_2_project.txt',
#  'git',
#  'data',
#  'requirements.txt',
#  '.DS_Store',
#  'README.md',
#  'configs',
#  '.git',
#  'run_lstm.ipynb',
#  'solution.ipynb',
#  '.vscode',
#  'src',
#  '.gitignore']

# %%
# !python3 src/lstm_train.py
# Out:
# Используем: cuda
# 100%|█████████████████████████████████████| 19767/19767 [03:32<00:00, 93.06it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 215.06it/s]
# Epoch 1, Train Loss: 3.0858, Val Loss: 2.1678, ROUGE-1: 0.0865, ROUGE-2: 0.0109
# 100%|█████████████████████████████████████| 19767/19767 [03:32<00:00, 92.85it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 219.97it/s]
# Epoch 2, Train Loss: 2.1445, Val Loss: 2.1291, ROUGE-1: 0.0998, ROUGE-2: 0.0180
# 100%|█████████████████████████████████████| 19767/19767 [03:33<00:00, 92.64it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 218.11it/s]
# Epoch 3, Train Loss: 2.1114, Val Loss: 2.1128, ROUGE-1: 0.0915, ROUGE-2: 0.0176
# 100%|█████████████████████████████████████| 19767/19767 [03:34<00:00, 92.21it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 217.24it/s]
# Epoch 4, Train Loss: 2.0936, Val Loss: 2.1036, ROUGE-1: 0.1031, ROUGE-2: 0.0137
# 100%|█████████████████████████████████████| 19767/19767 [03:33<00:00, 92.56it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 218.27it/s]
# Epoch 5, Train Loss: 2.0822, Val Loss: 2.0977, ROUGE-1: 0.1056, ROUGE-2: 0.0130
# 100%|█████████████████████████████████████| 19767/19767 [03:33<00:00, 92.66it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 218.36it/s]
# Epoch 6, Train Loss: 2.0731, Val Loss: 2.0939, ROUGE-1: 0.1057, ROUGE-2: 0.0206
# 100%|█████████████████████████████████████| 19767/19767 [03:33<00:00, 92.60it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 217.84it/s]
# Epoch 7, Train Loss: 2.0663, Val Loss: 2.0910, ROUGE-1: 0.0925, ROUGE-2: 0.0062
# 100%|█████████████████████████████████████| 19767/19767 [03:33<00:00, 92.59it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 219.59it/s]
# Epoch 8, Train Loss: 2.0605, Val Loss: 2.0887, ROUGE-1: 0.1030, ROUGE-2: 0.0177
# 100%|█████████████████████████████████████| 19767/19767 [03:34<00:00, 92.12it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 216.31it/s]
# Epoch 9, Train Loss: 2.0565, Val Loss: 2.0873, ROUGE-1: 0.1061, ROUGE-2: 0.0256
# 100%|█████████████████████████████████████| 19767/19767 [03:34<00:00, 92.25it/s]
# 100%|██████████████████████████████████████| 2471/2471 [00:11<00:00, 219.40it/s]
# Epoch 10, Train Loss: 2.0524, Val Loss: 2.0858, ROUGE-1: 0.1043, ROUGE-2: 0.0180
# Модель сохранена в models/lstm_model.pt
# Модель и словарь сохранены
