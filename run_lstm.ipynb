# %%
import torch
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
else:
    print("CUDA is not available")
# Out:
# Tesla T4

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
# !python src/lstm_train.py
# Out:
# python3: can't open file '/content/src/lstm_train.py': [Errno 2] No such file or directory
